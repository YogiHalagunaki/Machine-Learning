# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshika-123/Machine_Learning/blob/master/Automated_EDA_Using_Pandas_Profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ydata-profiling # install the correct package with the correct name

import seaborn as sns # import necessary libraries
from ydata_profiling import ProfileReport # import the correct class from the correct module

df = sns.load_dataset('tips') # load the dataset

profile = ProfileReport(df, explorative=True, dark_mode=True) # generate the profile report
profile.to_file('output.html') # save the report to an HTML file
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
